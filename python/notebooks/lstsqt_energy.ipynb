# %% [markdown]
# # Least-Squares Estimate of Cycling Parameters

# %%
import sys; sys.path.append('..')
import numpy as np
import fitparse
import pandas as pd
import math
import plotly.express as px

from utils.paths import data_folder

# %%
def parse_fitfile(
  filepath: str,
  columns: list[str],
  verbose: bool = False,
) -> pd.DataFrame:
  """Parse a .fit file into a format the simulator can use.

  Notes
  -----
  The file must include at least timestamp, distance, and altitude.
  """
  ff = fitparse.FitFile(filepath)
  df = {col: [] for col in columns}

  generator = ff.get_messages("record", with_definitions=True)
  messages = list(generator)

  for m in messages:
    if type(m) == fitparse.records.DefinitionMessage:
      continue

    record_data = m.get_values()

    if verbose:
      print(record_data.keys())

    if any([col not in record_data for col in df]):
      ts = record_data["timestamp"]
      if verbose:
        print(f"Skipping incomplete record @ {ts}")
      continue

    for col in df:
      df[col].append(record_data[col])

  return pd.DataFrame(df)


def preprocess_columns(df):
  """Preprocess grade."""
  df["dy"] = df.altitude.diff(1)
  df["dx"] = df.distance.diff(1)
  df["grade"] = (df.dy / df.dx).fillna(0)
  df["theta"] = df.grade.map(math.atan).fillna(0)
  df["v2"] = df.speed ** 2
  df["v2_diff"] = df.v2.diff(1).fillna(0)
  df["speed_diff"] = df.speed.diff(1).fillna(0)
  df["dt"] = df.timestamp.diff(1).fillna(0)
  df["P_prev_sec"] = df.power.shift(1).fillna(0)
  df.dt = df.dt.map(lambda x: x.total_seconds() if type(x) == pd.Timedelta else x)
  return df

# %%
def estimate_parameters(df: pd.DataFrame):
  G = 9.81 # m/s2
  m = 72 + 10 # kg
  rho = 1.225 # kg/m3

  dv = df.speed_diff.to_numpy()
  v0 = df.speed.to_numpy() - df.speed_diff.to_numpy()
  dv2 = df.v2_diff.to_numpy()
  dx = df.dx.to_numpy()
  dy = df.dy.to_numpy()
  dt = df.dt.to_numpy()
  P_legs = df.power.to_numpy()
  theta = df.theta.to_numpy()

  # Change in kinetic energy + change in potential energy from previous row to current row (t-1 -> t).
  b = 0.5*m*dv2 + m*G*dy
  c1 = dt * P_legs
  c2 = -dx * m * G * np.cos(theta)
  c3 = -0.5 * rho * dx * (v0**2 + v0*dv + (1/3)*dv**2)
  A = np.column_stack((c1, c2, c3))

  x, residuals, rank, s = np.linalg.lstsq(A, b)

  yhat = A @ x

  return x, residuals, rank, s, yhat, b


def estimate_parameters_constant_L(df: pd.DataFrame, L: float = 0.05):
  G = 9.81 # m/s2
  m = 72 + 10 # kg
  rho = 1.225 # kg/m3

  dv = df.speed_diff.to_numpy()
  v0 = df.speed.to_numpy() - df.speed_diff.to_numpy()
  dv2 = df.v2_diff.to_numpy()
  dx = df.dx.to_numpy()
  dy = df.dy.to_numpy()
  dt = df.dt.to_numpy()
  P_legs = df.power.to_numpy()
  theta = df.theta.to_numpy()

  # Change in kinetic energy + change in potential energy from previous row to current row (t-1 -> t).
  c1 = dt * P_legs
  b = 0.5*m*dv2 + m*G*dy - c1*(1-L)
  c2 = -dx * m * G * np.cos(theta)
  c3 = -0.5 * rho * dx * (v0**2 + v0*dv + (1/3)*dv**2)
  A = np.column_stack((c2, c3))

  x, residuals, rank, s = np.linalg.lstsq(A, b)

  yhat = A @ x

  return x, residuals, rank, s, yhat, b


def estimate_parameters_twostep(df: pd.DataFrame, verbose: bool = False):
  _, _, _, _, yhat, b = estimate_parameters(df)
  df["error"] = b - yhat
  df["abs_error"] = np.abs(df.error)
  before = len(df)

  df = df[df.abs_error < np.percentile(df.abs_error, 99)]

  if verbose:
    print(f"Removed {before - len(df)} outliers")

  x, residuals, rank, s, yhat, b = estimate_parameters(df)

  return x, residuals, rank, s, yhat, b, df

# %%
cols = [
  'timestamp',
  'distance',
  'altitude',
  'position_lat',
  'position_long',
  'power',
  'speed',
]
filepath = data_folder("fit/Boston_Tri.fit")
# filepath = data_folder("fit/Great_Brook_Farm.fit")
# filepath = data_folder("fit/IM_Santa_Cruz_70.3.fit")
df = parse_fitfile(filepath, cols, verbose=False)
df = preprocess_columns(df)
df.drop(labels=[0], inplace=True)

# Get rid of any rows where there is no change in time, or a long pause.
df = df[df.dt == 1]
# # Get rid of rows where speed is zero.
df = df[df.speed > 1]

# x, residuals, rank, s, y_hat, b = estimate_parameters(df)
# x, residuals, rank, s, y_hat, b, df2 = estimate_parameters_twostep(df, verbose=True)
# L = 1 - x[0]
# Crr = x[1]
# CdA = x[2]

chunk_size = 10

results = dict(Crr=[], CdA=[])
for i in range(0, len(df), chunk_size):
  _df = df[i:i+chunk_size]

  L = 0.05
  x, residuals, rank, s, y_hat, b = estimate_parameters_constant_L(_df, L=L)
  Crr = x[0]
  CdA = x[1]
  print(f"-- Optimized parameters:")
  print(f"* Crr = {Crr:.4f}")
  print(f"* CdA = {CdA:.4f}")
  results["Crr"].append(Crr)
  results["CdA"].append(CdA)
  # print(f"* Residuals = {residuals[0]:.4f}")
  # print(f"* Rank = {rank}")
  # print(f"* Singular values = {s}")
# Out:
# -- Optimized parameters:
# * Crr = -0.3829
# * CdA = 4.9619
# -- Optimized parameters:
# * Crr = -0.1163
# * CdA = 1.8192
# -- Optimized parameters:
# * Crr = 0.0591
# * CdA = -0.3398
# -- Optimized parameters:
# * Crr = 0.0641
# * CdA = -0.4492
# -- Optimized parameters:
# * Crr = 0.0713
# * CdA = -0.5395
# -- Optimized parameters:
# * Crr = -0.0513
# * CdA = 0.9847
# -- Optimized parameters:
# * Crr = -0.1492
# * CdA = 2.0760
# -- Optimized parameters:
# * Crr = -0.0044
# * CdA = 0.3842
# -- Optimized parameters:
# * Crr = -0.7106
# * CdA = 8.5969
# -- Optimized parameters:
# * Crr = 0.0314
# * CdA = -0.0215
# -- Optimized parameters:
# * Crr = 0.0138
# * CdA = 0.2274
# -- Optimized parameters:
# * Crr = -0.1501
# * CdA = 2.0312
# -- Optimized parameters:
# * Crr = 0.1644
# * CdA = -1.3993
# -- Optimized parameters:
# * Crr = 0.2902
# * CdA = -3.1568
# -- Optimized parameters:
# * Crr = -0.1381
# * CdA = 2.0728
# -- Optimized parameters:
# * Crr = -0.0965
# * CdA = 1.6242
# -- Optimized parameters:
# * Crr = 0.4819
# * CdA = -5.7079
# -- Optimized parameters:
# * Crr = 0.4413
# * CdA = -4.9336
# -- Optimized parameters:
# * Crr = -0.1839
# * CdA = 2.5776
# -- Optimized parameters:
# * Crr = -0.0633
# * CdA = 1.0601
# -- Optimized parameters:
# * Crr = -0.0776
# * CdA = 1.2587
# -- Optimized parameters:
# * Crr = 0.1830
# * CdA = -1.7414
# -- Optimized parameters:
# * Crr = 0.1035
# * CdA = -1.2499
# -- Optimized parameters:
# * Crr = 0.0214
# * CdA = 0.0472
# -- Optimized parameters:
# * Crr = 0.0986
# * CdA = -0.8535
# -- Optimized parameters:
# * Crr = -0.1384
# * CdA = 1.9610
# -- Optimized parameters:
# * Crr = 0.1820
# * CdA = -1.7343
# -- Optimized parameters:
# * Crr = 0.1618
# * CdA = -1.5047
# -- Optimized parameters:
# * Crr = 0.3157
# * CdA = -3.3110
# -- Optimized parameters:
# * Crr = 0.0104
# * CdA = 0.3609
# -- Optimized parameters:
# * Crr = -0.1008
# * CdA = 1.8965
# -- Optimized parameters:
# * Crr = -0.0811
# * CdA = 1.4624
# -- Optimized parameters:
# * Crr = -0.0000
# * CdA = 0.4267
# -- Optimized parameters:
# * Crr = -0.3822
# * CdA = 5.4867
# -- Optimized parameters:
# * Crr = -0.0923
# * CdA = 1.6268
# -- Optimized parameters:
# * Crr = 0.1146
# * CdA = -1.3504
# -- Optimized parameters:
# * Crr = 0.1672
# * CdA = -2.5779
# -- Optimized parameters:
# * Crr = -0.0391
# * CdA = 2.4491
# -- Optimized parameters:
# * Crr = 0.0773
# * CdA = -0.5365
# -- Optimized parameters:
# * Crr = -0.2514
# * CdA = 3.5671
# -- Optimized parameters:
# * Crr = 0.0631
# * CdA = -0.3462
# -- Optimized parameters:
# * Crr = -0.1798
# * CdA = 2.1980
# -- Optimized parameters:
# * Crr = 0.0387
# * CdA = 0.2820
# -- Optimized parameters:
# * Crr = -0.0223
# * CdA = 0.7077
# -- Optimized parameters:
# * Crr = -0.2187
# * CdA = 3.2448
# -- Optimized parameters:
# * Crr = -0.0199
# * CdA = 0.5015
# -- Optimized parameters:
# * Crr = -0.0641
# * CdA = 0.9247
# -- Optimized parameters:
# * Crr = -0.0388
# * CdA = 0.5684
# -- Optimized parameters:
# * Crr = 0.0153
# * CdA = 0.1610
# -- Optimized parameters:
# * Crr = 0.1525
# * CdA = -1.1338
# -- Optimized parameters:
# * Crr = -0.2728
# * CdA = 3.0138
# -- Optimized parameters:
# * Crr = 0.2033
# * CdA = -1.7357
# -- Optimized parameters:
# * Crr = -0.1296
# * CdA = 1.6036
# -- Optimized parameters:
# * Crr = -0.5362
# * CdA = 5.5942
# -- Optimized parameters:
# * Crr = 0.0762
# * CdA = -0.4593
# -- Optimized parameters:
# * Crr = 0.0461
# * CdA = -0.1861
# -- Optimized parameters:
# * Crr = 0.0403
# * CdA = -0.0897
# -- Optimized parameters:
# * Crr = 0.0235
# * CdA = 0.0882
# -- Optimized parameters:
# * Crr = 0.0531
# * CdA = -0.2622
# -- Optimized parameters:
# * Crr = -0.0656
# * CdA = 0.9439
# -- Optimized parameters:
# * Crr = 0.1311
# * CdA = -0.9726
# -- Optimized parameters:
# * Crr = -0.1479
# * CdA = 1.8469
# -- Optimized parameters:
# * Crr = 0.0334
# * CdA = -0.0732
# -- Optimized parameters:
# * Crr = 0.0200
# * CdA = 0.0639
# -- Optimized parameters:
# * Crr = -0.2311
# * CdA = 2.6818
# -- Optimized parameters:
# * Crr = -0.2406
# * CdA = 2.6196
# -- Optimized parameters:
# * Crr = 0.1261
# * CdA = -0.9568
# -- Optimized parameters:
# * Crr = -0.0516
# * CdA = 0.7762
# -- Optimized parameters:
# * Crr = 0.1339
# * CdA = -0.9948
# -- Optimized parameters:
# * Crr = -0.0008
# * CdA = 0.2117
# -- Optimized parameters:
# * Crr = 0.0084
# * CdA = 0.1367
# -- Optimized parameters:
# * Crr = 0.3689
# * CdA = -2.8879
# -- Optimized parameters:
# * Crr = -0.0075
# * CdA = 1.0343
# -- Optimized parameters:
# * Crr = 0.0317
# * CdA = 0.0500
# -- Optimized parameters:
# * Crr = -0.1821
# * CdA = 2.7680
# -- Optimized parameters:
# * Crr = 0.0928
# * CdA = -0.7192
# -- Optimized parameters:
# * Crr = -0.0038
# * CdA = 0.4614
# -- Optimized parameters:
# * Crr = -0.2646
# * CdA = 3.8431
# -- Optimized parameters:
# * Crr = -0.1912
# * CdA = 2.9423
# -- Optimized parameters:
# * Crr = -0.0418
# * CdA = 0.8575
# -- Optimized parameters:
# * Crr = -0.1339
# * CdA = 2.0976
# -- Optimized parameters:
# * Crr = 0.1408
# * CdA = -1.5025
# -- Optimized parameters:
# * Crr = 0.1018
# * CdA = -0.8809
# -- Optimized parameters:
# * Crr = 0.2128
# * CdA = -1.9594
# -- Optimized parameters:
# * Crr = -0.0685
# * CdA = 1.0640
# -- Optimized parameters:
# * Crr = -0.2653
# * CdA = 3.1699
# -- Optimized parameters:
# * Crr = 0.0389
# * CdA = -0.1309
# -- Optimized parameters:
# * Crr = -0.0784
# * CdA = 1.1702
# -- Optimized parameters:
# * Crr = -0.3211
# * CdA = 3.7485
# -- Optimized parameters:
# * Crr = 0.4656
# * CdA = -4.4704
# -- Optimized parameters:
# * Crr = 0.0470
# * CdA = -0.1340
# -- Optimized parameters:
# * Crr = -0.1317
# * CdA = 1.8497
# -- Optimized parameters:
# * Crr = -0.0773
# * CdA = 1.3015
# -- Optimized parameters:
# * Crr = 0.0623
# * CdA = -0.3381
# -- Optimized parameters:
# * Crr = 0.3400
# * CdA = -3.6212
# -- Optimized parameters:
# * Crr = -0.1181
# * CdA = 1.9248
# -- Optimized parameters:
# * Crr = -0.0080
# * CdA = 0.4647
# -- Optimized parameters:
# * Crr = 0.3788
# * CdA = -4.1051
# -- Optimized parameters:
# * Crr = -0.0562
# * CdA = 1.3316
# -- Optimized parameters:
# * Crr = 0.0499
# * CdA = -0.5649
# -- Optimized parameters:
# * Crr = 0.0128
# * CdA = 0.2136
# -- Optimized parameters:
# * Crr = -0.2120
# * CdA = 2.6465
# -- Optimized parameters:
# * Crr = 0.2433
# * CdA = -2.2941
# -- Optimized parameters:
# * Crr = 0.0659
# * CdA = -0.3950
# -- Optimized parameters:
# * Crr = -0.1656
# * CdA = 2.1840
# -- Optimized parameters:
# * Crr = 0.0891
# * CdA = -0.4924
# -- Optimized parameters:
# * Crr = 0.0181
# * CdA = 0.7115
# -- Optimized parameters:
# * Crr = 0.2437
# * CdA = -3.7321
# -- Optimized parameters:
# * Crr = -0.0113
# * CdA = 0.4563
# -- Optimized parameters:
# * Crr = -0.0599
# * CdA = 1.1910
# -- Optimized parameters:
# * Crr = -0.0809
# * CdA = 1.3329
# -- Optimized parameters:
# * Crr = 0.0227
# * CdA = 0.1754
# -- Optimized parameters:
# * Crr = -0.0915
# * CdA = 1.5272
# -- Optimized parameters:
# * Crr = 0.1114
# * CdA = -0.9958
# -- Optimized parameters:
# * Crr = -0.0457
# * CdA = 1.6469
# -- Optimized parameters:
# * Crr = 0.0244
# * CdA = 0.2771
# -- Optimized parameters:
# * Crr = 0.0483
# * CdA = -0.1966
# -- Optimized parameters:
# * Crr = 0.0571
# * CdA = -0.4119
# -- Optimized parameters:
# * Crr = 0.3453
# * CdA = -3.8217
# -- Optimized parameters:
# * Crr = 0.0309
# * CdA = 0.3462
# -- Optimized parameters:
# * Crr = 0.0953
# * CdA = -1.1173
# -- Optimized parameters:
# * Crr = -0.0791
# * CdA = 1.3511
# -- Optimized parameters:
# * Crr = 0.0329
# * CdA = -0.1918
# -- Optimized parameters:
# * Crr = -0.0868
# * CdA = 1.0538
# -- Optimized parameters:
# * Crr = 0.0309
# * CdA = -0.0271
# -- Optimized parameters:
# * Crr = 0.0895
# * CdA = -0.5282
# -- Optimized parameters:
# * Crr = 0.0150
# * CdA = 0.1680
# -- Optimized parameters:
# * Crr = 0.0635
# * CdA = -0.3217
# -- Optimized parameters:
# * Crr = 0.0289
# * CdA = -0.0468
# -- Optimized parameters:
# * Crr = 0.1684
# * CdA = -1.3679
# -- Optimized parameters:
# * Crr = -0.1316
# * CdA = 1.5791
# -- Optimized parameters:
# * Crr = -0.0237
# * CdA = 0.5509
# -- Optimized parameters:
# * Crr = -0.1017
# * CdA = 1.3178
# -- Optimized parameters:
# * Crr = 0.0033
# * CdA = 0.2615
# -- Optimized parameters:
# * Crr = -0.1961
# * CdA = 2.5191
# -- Optimized parameters:
# * Crr = -0.0897
# * CdA = 1.3144
# -- Optimized parameters:
# * Crr = -0.1017
# * CdA = 1.3155
# -- Optimized parameters:
# * Crr = -0.0402
# * CdA = 0.7297
# -- Optimized parameters:
# * Crr = -0.0289
# * CdA = 0.6100
# -- Optimized parameters:
# * Crr = 0.0382
# * CdA = -0.0842
# -- Optimized parameters:
# * Crr = 0.0610
# * CdA = -0.3856
# -- Optimized parameters:
# * Crr = -0.0466
# * CdA = 0.8634
# -- Optimized parameters:
# * Crr = -0.1304
# * CdA = 1.5949
# -- Optimized parameters:
# * Crr = -0.0439
# * CdA = 0.7294
# -- Optimized parameters:
# * Crr = 0.0330
# * CdA = -0.0380
# -- Optimized parameters:
# * Crr = 0.3459
# * CdA = -3.1341
# -- Optimized parameters:
# * Crr = -0.2348
# * CdA = 2.3790
# -- Optimized parameters:
# * Crr = -0.1305
# * CdA = 1.3641
# -- Optimized parameters:
# * Crr = 0.3096
# * CdA = -2.3087
# -- Optimized parameters:
# * Crr = 0.0085
# * CdA = 1.4456
# -- Optimized parameters:
# * Crr = 0.1009
# * CdA = -1.1120
# -- Optimized parameters:
# * Crr = 0.2526
# * CdA = -2.9061
# -- Optimized parameters:
# * Crr = 0.1388
# * CdA = -1.1831
# -- Optimized parameters:
# * Crr = -0.7827
# * CdA = 9.4578
# -- Optimized parameters:
# * Crr = -0.7865
# * CdA = 9.2160
# -- Optimized parameters:
# * Crr = 0.1527
# * CdA = -1.3177
# -- Optimized parameters:
# * Crr = 0.2267
# * CdA = -2.2062
# -- Optimized parameters:
# * Crr = -0.0153
# * CdA = 0.5212
# -- Optimized parameters:
# * Crr = 0.0563
# * CdA = -0.3655
# -- Optimized parameters:
# * Crr = -0.1734
# * CdA = 2.2950
# -- Optimized parameters:
# * Crr = 0.0689
# * CdA = -0.4233
# -- Optimized parameters:
# * Crr = 0.0796
# * CdA = -0.4918
# -- Optimized parameters:
# * Crr = -0.1942
# * CdA = 2.4970
# -- Optimized parameters:
# * Crr = -0.1837
# * CdA = 2.4240
# -- Optimized parameters:
# * Crr = 0.0043
# * CdA = 0.2521
# -- Optimized parameters:
# * Crr = -0.1028
# * CdA = 1.3762
# -- Optimized parameters:
# * Crr = -0.0884
# * CdA = 1.3379
# -- Optimized parameters:
# * Crr = -0.2513
# * CdA = 3.3455
# -- Optimized parameters:
# * Crr = -0.1999
# * CdA = 2.6391
# -- Optimized parameters:
# * Crr = -0.1629
# * CdA = 2.3565
# -- Optimized parameters:
# * Crr = 0.1244
# * CdA = -1.1464
# -- Optimized parameters:
# * Crr = 0.0470
# * CdA = -0.1078
# -- Optimized parameters:
# * Crr = -0.3020
# * CdA = 4.1228
# -- Optimized parameters:
# * Crr = -0.1391
# * CdA = 1.9251
# -- Optimized parameters:
# * Crr = 0.0643
# * CdA = -0.4126
# -- Optimized parameters:
# * Crr = 0.1185
# * CdA = -1.0295
# -- Optimized parameters:
# * Crr = -0.0577
# * CdA = 1.2638
# -- Optimized parameters:
# * Crr = 0.1763
# * CdA = -2.1386
# -- Optimized parameters:
# * Crr = -0.3036
# * CdA = 4.0170
# -- Optimized parameters:
# * Crr = 0.6057
# * CdA = -6.9848
# -- Optimized parameters:
# * Crr = -0.1685
# * CdA = 2.5345
# -- Optimized parameters:
# * Crr = 0.2632
# * CdA = -3.1168
# -- Optimized parameters:
# * Crr = 0.2944
# * CdA = -4.1250
# -- Optimized parameters:
# * Crr = 0.0788
# * CdA = -0.9139
# -- Optimized parameters:
# * Crr = 0.0452
# * CdA = -0.1285
# -- Optimized parameters:
# * Crr = -0.1093
# * CdA = 1.9660
# -- Optimized parameters:
# * Crr = -0.1546
# * CdA = 2.6959
# -- Optimized parameters:
# * Crr = -0.1607
# * CdA = 2.2940
# -- Optimized parameters:
# * Crr = 0.0291
# * CdA = 0.1711
# -- Optimized parameters:
# * Crr = -0.0698
# * CdA = 1.3412
# -- Optimized parameters:
# * Crr = -0.0418
# * CdA = 1.1248
# -- Optimized parameters:
# * Crr = 0.0949
# * CdA = -0.6334
# -- Optimized parameters:
# * Crr = -0.0883
# * CdA = 2.0144
# -- Optimized parameters:
# * Crr = 0.1545
# * CdA = -1.7088
# -- Optimized parameters:
# * Crr = 0.0880
# * CdA = -0.7994
# -- Optimized parameters:
# * Crr = -0.1708
# * CdA = 2.6629
# -- Optimized parameters:
# * Crr = 0.2638
# * CdA = -2.9029
# -- Optimized parameters:
# * Crr = -0.0232
# * CdA = 1.3808
# -- Optimized parameters:
# * Crr = 0.0959
# * CdA = -0.9824
# -- Optimized parameters:
# * Crr = 0.0147
# * CdA = 0.1011
# -- Optimized parameters:
# * Crr = -0.1848
# * CdA = 2.1445
# -- Optimized parameters:
# * Crr = -0.0425
# * CdA = 0.7118
# -- Optimized parameters:
# * Crr = -0.2596
# * CdA = 2.4597
# -- Optimized parameters:
# * Crr = -0.2908
# * CdA = 2.9520
# -- Optimized parameters:
# * Crr = 0.0222
# * CdA = 0.0940
# -- Optimized parameters:
# * Crr = 0.2273
# * CdA = -1.9154
# -- Optimized parameters:
# * Crr = -0.2998
# * CdA = 3.0997
# -- Optimized parameters:
# * Crr = -0.2358
# * CdA = 2.4813
# -- Optimized parameters:
# * Crr = -0.0067
# * CdA = 0.3814
# -- Optimized parameters:
# * Crr = -0.0343
# * CdA = 0.5909
# -- Optimized parameters:
# * Crr = -0.3086
# * CdA = 3.1680
# -- Optimized parameters:
# * Crr = 0.4153
# * CdA = -3.6638
# -- Optimized parameters:
# * Crr = 0.0540
# * CdA = -0.2340
# -- Optimized parameters:
# * Crr = -0.1081
# * CdA = 1.4182
# -- Optimized parameters:
# * Crr = -0.1095
# * CdA = 1.3894
# -- Optimized parameters:
# * Crr = -0.0158
# * CdA = 0.3998
# -- Optimized parameters:
# * Crr = 0.0139
# * CdA = 0.1600
# -- Optimized parameters:
# * Crr = -0.0432
# * CdA = 0.7310
# -- Optimized parameters:
# * Crr = -0.1542
# * CdA = 2.0056
# -- Optimized parameters:
# * Crr = -0.1929
# * CdA = 2.1844
# -- Optimized parameters:
# * Crr = 0.1691
# * CdA = -1.3764
# -- Optimized parameters:
# * Crr = 0.0822
# * CdA = -0.5259
# -- Optimized parameters:
# * Crr = -0.1236
# * CdA = 1.3599
# -- Optimized parameters:
# * Crr = 0.1327
# * CdA = -0.9539
# -- Optimized parameters:
# * Crr = -0.1872
# * CdA = 2.0145
# -- Optimized parameters:
# * Crr = 0.0359
# * CdA = 0.0708
# -- Optimized parameters:
# * Crr = 0.0653
# * CdA = -0.3620
# -- Optimized parameters:
# * Crr = 0.0933
# * CdA = -0.8814
# -- Optimized parameters:
# * Crr = -0.0870
# * CdA = 1.3762
# -- Optimized parameters:
# * Crr = -0.0916
# * CdA = 1.2961
# -- Optimized parameters:
# * Crr = 0.0076
# * CdA = 0.2877
# -- Optimized parameters:
# * Crr = 0.2147
# * CdA = -2.0192
# -- Optimized parameters:
# * Crr = 0.1018
# * CdA = -0.7296
# -- Optimized parameters:
# * Crr = 0.0611
# * CdA = -0.3554
# -- Optimized parameters:
# * Crr = -0.1365
# * CdA = 1.9632
# -- Optimized parameters:
# * Crr = 0.1654
# * CdA = -1.7570
# -- Optimized parameters:
# * Crr = -0.0477
# * CdA = 0.9920
# -- Optimized parameters:
# * Crr = -0.0461
# * CdA = 0.9370
# -- Optimized parameters:
# * Crr = 0.1010
# * CdA = -0.7550
# -- Optimized parameters:
# * Crr = 0.1812
# * CdA = -1.6967
# -- Optimized parameters:
# * Crr = -0.1734
# * CdA = 2.3684
# -- Optimized parameters:
# * Crr = 0.0701
# * CdA = -0.4711
# -- Optimized parameters:
# * Crr = -0.0780
# * CdA = 1.1726
# -- Optimized parameters:
# * Crr = 0.1207
# * CdA = -0.8940
# -- Optimized parameters:
# * Crr = -0.2923
# * CdA = 4.1526
# -- Optimized parameters:
# * Crr = -0.0141
# * CdA = 0.5067
# -- Optimized parameters:
# * Crr = -0.0262
# * CdA = 0.7645
# -- Optimized parameters:
# * Crr = -0.0293
# * CdA = 0.7912
# -- Optimized parameters:
# * Crr = -0.0420
# * CdA = 0.8878
# -- Optimized parameters:
# * Crr = -0.0710
# * CdA = 1.2810
# -- Optimized parameters:
# * Crr = 0.0670
# * CdA = -0.4369
# -- Optimized parameters:
# * Crr = 0.0924
# * CdA = -0.7022
# -- Optimized parameters:
# * Crr = -0.0055
# * CdA = 0.4792
# -- Optimized parameters:
# * Crr = 0.0863
# * CdA = -1.1013
# -- Optimized parameters:
# * Crr = 0.0182
# * CdA = -0.0495
# -- Optimized parameters:
# * Crr = 0.1884
# * CdA = -2.1714
# -- Optimized parameters:
# * Crr = 0.0254
# * CdA = 0.0791
# -- Optimized parameters:
# * Crr = 0.0807
# * CdA = -0.5884
# -- Optimized parameters:
# * Crr = 0.1423
# * CdA = -1.4633
# -- Optimized parameters:
# * Crr = -0.0195
# * CdA = 0.6767
# -- Optimized parameters:
# * Crr = 0.1532
# * CdA = -1.2807
# -- Optimized parameters:
# * Crr = -0.0766
# * CdA = 2.4287
# -- Optimized parameters:
# * Crr = 0.0031
# * CdA = 0.2214
# -- Optimized parameters:
# * Crr = -0.1240
# * CdA = 1.9056
# -- Optimized parameters:
# * Crr = -0.0202
# * CdA = 0.5671
# -- Optimized parameters:
# * Crr = 0.4873
# * CdA = -5.1222
# -- Optimized parameters:
# * Crr = -0.0617
# * CdA = 1.2010
# -- Optimized parameters:
# * Crr = 0.5795
# * CdA = -7.1779
# -- Optimized parameters:
# * Crr = 0.1815
# * CdA = -1.4975
# -- Optimized parameters:
# * Crr = -0.0085
# * CdA = 0.8994
# -- Optimized parameters:
# * Crr = 0.0204
# * CdA = 0.1179
# -- Optimized parameters:
# * Crr = 0.1008
# * CdA = -0.9513
# -- Optimized parameters:
# * Crr = -0.0101
# * CdA = 0.5206
# -- Optimized parameters:
# * Crr = 0.0998
# * CdA = -0.8641
# -- Optimized parameters:
# * Crr = -0.0685
# * CdA = 2.3105
# -- Optimized parameters:
# * Crr = 0.0299
# * CdA = 0.0295
# -- Optimized parameters:
# * Crr = 0.3105
# * CdA = -3.3332
# -- Optimized parameters:
# * Crr = -0.0186
# * CdA = 0.4120
# -- Optimized parameters:
# * Crr = 0.0700
# * CdA = -0.3905
# -- Optimized parameters:
# * Crr = -0.0078
# * CdA = 0.2467
# -- Optimized parameters:
# * Crr = -0.1074
# * CdA = 1.2688
# -- Optimized parameters:
# * Crr = 0.0166
# * CdA = 0.1792
# -- Optimized parameters:
# * Crr = 0.1441
# * CdA = -1.2126
# -- Optimized parameters:
# * Crr = 0.1547
# * CdA = -1.3203
# -- Optimized parameters:
# * Crr = 0.0973
# * CdA = -0.8069
# -- Optimized parameters:
# * Crr = 0.1253
# * CdA = -0.9943
# -- Optimized parameters:
# * Crr = -0.0193
# * CdA = 0.4518
# -- Optimized parameters:
# * Crr = 0.0109
# * CdA = 0.1493
# -- Optimized parameters:
# * Crr = -0.1658
# * CdA = 1.8746
# -- Optimized parameters:
# * Crr = 0.0181
# * CdA = 0.0616
# -- Optimized parameters:
# * Crr = -0.3585
# * CdA = 4.1953
# -- Optimized parameters:
# * Crr = -0.3691
# * CdA = 4.1901
# -- Optimized parameters:
# * Crr = -0.2037
# * CdA = 2.2283
# -- Optimized parameters:
# * Crr = 0.0418
# * CdA = -0.0683
# -- Optimized parameters:
# * Crr = 0.0377
# * CdA = -0.1349
# -- Optimized parameters:
# * Crr = -0.3159
# * CdA = 3.7760
# -- Optimized parameters:
# * Crr = -0.1748
# * CdA = 2.1148
# -- Optimized parameters:
# * Crr = 0.0941
# * CdA = -0.6346
# -- Optimized parameters:
# * Crr = 0.0542
# * CdA = -0.3051
# -- Optimized parameters:
# * Crr = -0.5263
# * CdA = 5.8945
# -- Optimized parameters:
# * Crr = 0.0830
# * CdA = -0.6606
# -- Optimized parameters:
# * Crr = -0.2167
# * CdA = 2.4308
# -- Optimized parameters:
# * Crr = 0.2153
# * CdA = -2.0331
# -- Optimized parameters:
# * Crr = -0.0580
# * CdA = 0.9724
# -- Optimized parameters:
# * Crr = 0.0328
# * CdA = 0.4707
# -- Optimized parameters:
# * Crr = 0.0091
# * CdA = 0.9854
# /var/folders/0z/fnhwmrr91f362mk6_bndszhw0000gn/T/ipykernel_28863/1679689537.py:50: FutureWarning:
#
# `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
fig = px.scatter(x=results["CdA"], y=results["Crr"])
fig.show()

# %%
fig = px.line(df, x="timestamp", y=["error"], title="Actual vs. Predicted Acceleration")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 fig = px.line(df, x="timestamp", y=["error"], title="Actual vs. Predicted Acceleration")
#       2 fig.show()
#
# File ~/envs/triathlon-tools-J8FESCDJ/lib/python3.12/site-packages/plotly/express/_chart_types.py:264, in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     216 def line(
#     217     data_frame=None,
#     218     x=None,
#    (...)
#     258     height=None,
#     259 ) -> go.Figure:
#     260     """
#     261     In a 2D line plot, each row of `data_frame` is represented as vertex of
#     262     a polyline mark in 2D space.
#     263     """
# --> 264     return make_figure(args=locals(), constructor=go.Scatter)
#
# File ~/envs/triathlon-tools-J8FESCDJ/lib/python3.12/site-packages/plotly/express/_core.py:2090, in make_figure(args, constructor, trace_patch, layout_patch)
#    2087 layout_patch = layout_patch or {}
#    2088 apply_default_cascade(args)
# -> 2090 args = build_dataframe(args, constructor)
#    2091 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2092     args = process_dataframe_hierarchy(args)
#
# File ~/envs/triathlon-tools-J8FESCDJ/lib/python3.12/site-packages/plotly/express/_core.py:1492, in build_dataframe(args, constructor)
#    1489     args["color"] = None
#    1490 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1492 df_output, wide_id_vars = process_args_into_dataframe(
#    1493     args, wide_mode, var_name, value_name
#    1494 )
#    1496 # now that `df_output` exists and `args` contains only references, we complete
#    1497 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1498 # df_output
#    1500 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~/envs/triathlon-tools-J8FESCDJ/lib/python3.12/site-packages/plotly/express/_core.py:1253, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1250         col_name = _check_name_not_reserved(field, reserved_names)
#    1252     if length and len(argument) != length:
# -> 1253         raise ValueError(
#    1254             "All arguments should have the same length. "
#    1255             "The length of argument `%s` is %d, whereas the "
#    1256             "length of  previously-processed arguments %s is %d"
#    1257             % (field, len(argument), str(list(df_output.keys())), length)
#    1258         )
#    1259     df_output[str(col_name)] = to_unindexed_series(argument, str(col_name))
#    1261 # Finally, update argument with column name now that column exists
#
# ValueError: All arguments should have the same length. The length of argument `y` is 1, whereas the length of  previously-processed arguments ['timestamp'] is 8775

# %%
fig = px.line(df, x="timestamp", y=["altitude"], title="Variables")
fig.show()

# %%
fig = px.histogram(df2, x="abs_error", title="Error Distribution")
fig.show()

np.percentile(df2.abs_error, 95)

# %%
def virtual_elevation(df: pd.DataFrame, m: float, CdA: float, Crr: float, L: float, rho: float = 1.225):
  G = 9.81 # m/s2

  dv = df.speed_diff.to_numpy()
  v0 = df.speed.to_numpy() - df.speed_diff.to_numpy()
  dv2 = df.v2_diff.to_numpy()
  dx = df.dx.to_numpy()
  dy = df.dy.to_numpy()
  dt = df.dt.to_numpy()
  P_legs = df.power.to_numpy()
  theta = df.theta.to_numpy()

  W_legs = P_legs * dt * (1 - L)
  W_roll = Crr * dx * m * G * np.cos(theta)
  W_air = 0.5 * rho * CdA * dx * (v0**2 + v0*dv + (1/3)*dv**2)

  delta_kinetic = 0.5 * m * dv2

  delta_h = (W_legs - W_roll - W_air - delta_kinetic) / (m * G)
  df["virtual_elevation"] = delta_h.cumsum() + df.altitude.iloc[0]

  return df

# %%
cols = [
  'timestamp',
  'distance',
  'altitude',
  'position_lat',
  'position_long',
  'power',
  'speed',
]
filepath = data_folder("fit/Boston_Tri.fit")
# filepath = data_folder("fit/Great_Brook_Farm.fit")
# filepath = data_folder("fit/IM_Santa_Cruz_70.3.fit")
df = parse_fitfile(filepath, cols, verbose=False)
df = preprocess_columns(df)
df.drop(labels=[0], inplace=True)

m = 72 + 10 # kg
rho = 1.225 # kg/m3
CdA = 0.30
Crr = 0.006
L = 0.05
df = virtual_elevation(df, m, CdA, Crr, L, rho)
df
# Out:
#                timestamp  distance  altitude  position_lat  position_long  \
# 1    2023-08-27 11:49:54    432.69       9.4     504987797     -847636027
# 2    2023-08-27 11:49:55    443.25       9.4     504988760     -847635306
# 3    2023-08-27 11:49:56    453.73       9.4     504989752     -847634498
# 4    2023-08-27 11:49:57    464.27       9.4     504990713     -847633678
# 5    2023-08-27 11:49:58    474.55       9.6     504991659     -847632949
# ...                  ...       ...       ...           ...            ...
# 3056 2023-08-27 12:40:49  32763.37       7.4     504936313     -847643406
# 3057 2023-08-27 12:40:50  32771.25       7.2     504935639     -847642683
# 3058 2023-08-27 12:40:51  32779.38       7.2     504934989     -847641945
# 3059 2023-08-27 12:40:52  32787.59       7.0     504934349     -847641128
# 3060 2023-08-27 12:40:53  32795.49       7.0     504933757     -847640312
#
#       power   speed   dy     dx     grade     theta          v2    v2_diff  \
# 1       333  10.545  0.2  10.53  0.018993  0.018991  111.197025   3.328029
# 2       354  10.537  0.0  10.56  0.000000  0.000000  111.028369  -0.168656
# 3       325  10.515  0.0  10.48  0.000000  0.000000  110.565225  -0.463144
# 4       306  10.373  0.0  10.54  0.000000  0.000000  107.599129  -2.966096
# 5       256  10.387  0.2  10.28  0.019455  0.019453  107.889769   0.290640
# ...     ...     ...  ...    ...       ...       ...         ...        ...
# 3056    375   7.722  0.0   7.69  0.000000  0.000000   59.629284  11.936448
# 3057    401   7.811 -0.2   7.88 -0.025381 -0.025375   61.011721   1.382437
# 3058    403   8.095  0.0   8.13  0.000000  0.000000   65.529025   4.517304
# 3059    386   7.955 -0.2   8.21 -0.024361 -0.024356   63.282025  -2.247000
# 3060    210   7.791  0.0   7.90  0.000000  0.000000   60.699681  -2.582344
#
#       speed_diff   dt  P_prev_sec  virtual_elevation
# 1          0.159  1.0       305.0           9.297020
# 2         -0.008  1.0       333.0           9.392298
# 3         -0.022  1.0       354.0           9.471605
# 4         -0.142  1.0       325.0           9.658302
# 5          0.014  1.0       306.0           9.631143
# ...          ...  ...         ...                ...
# 3056       0.816  1.0       227.0         -30.370720
# 3057       0.089  1.0       375.0         -30.123449
# 3058       0.284  1.0       401.0         -30.044010
# 3059      -0.140  1.0       403.0         -29.643651
# 3060      -0.164  1.0       386.0         -29.423286
#
# [3060 rows x 17 columns]

# %%
fig = px.line(df, x="timestamp", y=["altitude", "virtual_elevation"], title="Actual vs. Virtual Elevation")
fig.show()
